# %%
pip install adjustText
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for adjustText: filename=adjustText-0.7.3-py3-none-any.whl size=7074 sha256=5b4d3e1f196c983b8416905733071ba9f032b6a420befa885d260c0a0cb045b3
#   Stored in directory: c:\users\matteolai\appdata\local\pip\cache\wheels\6b\1d\79\4326d5f3a7d86fb9900e5564e7a0f98b552da5103ca762f24f
# Successfully built adjustText
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from adjustText import adjust_text

# %%
# Text Variables
Header = 'Candidature for Junior Python Developer'
Name = 'MATTEO LAI'
Title = 'Junior Python Developer'
Contact = 'Krakow, Poland\nwww.linkedin.com/in/matteo-lai-71437aa4\nhttps://github.com/matteolai1988\nMobile:+48 792029084\nMail:dottmatteolai@gmail.com'
ProjectsHeader = ' PYTHON PROJECTS'
ProjectOneTitle = 'Image Automation'
ProjectOneDesc = 'Manipulate and modify images\nExtract text from scanned documents and images using Pillow library in Python\n'
ProjectTwoTitle = 'Download Automator'
ProjectTwoDesc = 'Download files from the Internet and route the files to your favorite directories\n according to the file type using Watchdog library in Python\n'
ProjectThreeTitle = 'E-Bay Price Tracker'
ProjectThreeDesc = 'Extract the average price of a product in E-Bay using BeautifulSoup\n and Numpy libraries in Python\n'
Portfolio = 'Portfolio: https://github.com/matteolai1988'
WorkHeader = 'WORK EXPERIENCE'
WorkOneTitle = 'Uber / IT Specialist - Bugs and Outages Expert'
WorkOneTime = '4/2022-Present'
WorkOneDesc = 'Handling real-time bug and outage support for our global support agents.\n Providing a resource to identify and escalate system issues to engineering.\n Monitoring outages and communicating their customer impact to stakeholders.\n Specializing in the Driver/Courier line of business.\n'
WorkTwoTitle = 'HCL Technologies Poland / IT Analyst - IT Service Desk'
WorkTwoTime = '11/2019-3/2022'
WorkTwoDesc = 'Provide first line technical support, answering user queries relating to hardware\nand software problems, via phone, chat or email.\nKnowledge Base update regarding Acrobat Reader,\nDMS application and Microsoft Teams.'
WorkThreeTitle = 'Majorel Polska / Content Reviewer - Google Shopping Project'
WorkThreeTime = '10/2018-09/2019'
WorkThreeDesc = 'Evaluate web pages and advertising content in conjunction with client policy.\nVisually navigate and review images, videos, accounts and text-based content\nEscalate violations of client policies using internal tools.'
EduHeader = 'EDUCATION'
EduOneTitle = 'University of Cagliari, Master Degree in Law'
EduOneTime = '2007-2012'
EduOneDesc = 'Thesis in Family Law regarding “The cohabitation contracts”'
EduTwoTitle = 'University of Cagliari, Specialisation School for Legal Professions'
EduTwoTime = '2012-2014'
SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Pandas\n- NumPy\n- Data Visualization\n- Data Cleaning\n- Command Line\n- Git and Version Control\n- SQL\JQL\n- APIs\n- Machine Learning\n- Data Manipulation\n- Excel\n- Django\n- Flask\n- Web Scraping\n- Incidents Management\n- Data Analysis\n- Jira'
ExtrasTitle = 'PCEP (Python Institute)\nCertified Entry-Level\n Python Programmer'
#fundamental terms and definitions (e.g. compilation vs. interpretation), Python's logic and structure (e.g. keywords, instructions, indentation), literals, variables, and numeral systems, operators and data types, I/O operations, control flow mechanisms (conditional blocks and loops), data collections (lists, tuples, dictionaries, strings), functions (decomposition, built-in and user-defined functions, organizing interaction between functions and their environment, generators, recursion), exceptions (exception handling, hierarchies), as well as the essentials of Python programming language syntax, semantics, and the runtime environment.
ExtrasDesc = 'Learned fundamental terms and definitions\nlogic and structure, literals, variables and\nnumeral systems, operators and data types,\ncontrol flow mechanisms, data collections,\n functions and exceptions'
CodeTitle = 'LinkedIn and Kaggle Certificates\nDjango\nFlask\nWeb Scraping\nRest APIs\nMachine Learning\nData Analysis\nPandas\nPython\nUsing SQL with Python\nData Cleaning\nData Visualization\nTime Series'
# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline
# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(8.5, 11))
# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)
# set background color
ax.set_facecolor('white')
# remove axes
plt.axis('off')
# add text
plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.75)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(ProjectsHeader, (.02,.86), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.02,.832), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.04,.78), weight='regular', fontsize=9)
#plt.annotate(ProjectTwoTitle, (.02,.745), weight='bold', fontsize=10)
#plt.annotate(ProjectTwoDesc, (.04,.71), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.02,.745), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.68), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.02,.672), weight='bold', fontsize=10)
#plt.annotate(ProjectThreeDesc, (.04,.638), weight='regular', fontsize=9)
plt.annotate(ProjectThreeDesc, (.04,.623), weight='regular', fontsize=9)
plt.annotate(Portfolio, (.02,.6), weight='bold', fontsize=10)
plt.annotate(WorkHeader, (.02,.54), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(WorkOneTitle, (.02,.508), weight='bold', fontsize=10)
plt.annotate(WorkOneTime, (.02,.493), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(WorkOneDesc, (.04,.445), weight='regular', fontsize=9)
plt.annotate(WorkOneDesc, (.04,.410), weight='regular', fontsize=9)
#plt.annotate(WorkTwoTitle, (.02,.4), weight='bold', fontsize=10)
#plt.annotate(WorkTwoTime, (.02,.385), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(WorkTwoDesc, (.04,.337), weight='regular', fontsize=9)
#plt.annotate(WorkTwoTitle, (.02,.4), weight='bold', fontsize=10)
#plt.annotate(WorkTwoTime, (.02,.385), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(WorkTwoDesc, (.04,.337), weight='regular', fontsize=9)
plt.annotate(WorkTwoTitle, (.02,.4), weight='bold', fontsize=10)
plt.annotate(WorkTwoTime, (.02,.385), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkTwoDesc, (.04,.310), weight='regular', fontsize=9)
plt.annotate(WorkThreeTitle, (.02,.275), weight='bold', fontsize=10)
plt.annotate(WorkThreeTime, (.02,.26), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(WorkThreeDesc, (.04,.247), weight='regular', fontsize=9)
plt.annotate(WorkThreeDesc, (.04,.210), weight='regular', fontsize=9)
plt.annotate(EduHeader, (.02,.185), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.155), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.14), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc, (.04,.125), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.02,.08), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.065), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
#plt.annotate(SkillsDesc, (.7,.56), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.46), weight='regular', fontsize=10, color='#ffffff')
#plt.annotate(ExtrasTitle, (.7,.43), weight='bold', fontsize=10, color='#ffffff')
#plt.annotate(ExtrasDesc, (.7,.345), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(ExtrasTitle, (.7,.40), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(ExtrasDesc, (.7,.320), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(CodeTitle, (.7,.1), weight='bold', fontsize=9, color='#ffffff')
#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
#arr_code = mpimg.imread('resume matteo lai.png')
#imagebox = OffsetImage(arr_code, zoom=0.5)
#ab = AnnotationBbox(imagebox, (0.84, 0.12))
#ax.add_artist(ab)
plt.savefig('resume matteo lai 20 january 2023.png', dpi=300, bbox_inches='tight')

# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

image_1 = Image.open(r'resume matteo lai.png')
im_1 = image_1.convert('RGB')
im_1.save(r'matteo lai cv 20 january 2023.pdf')
